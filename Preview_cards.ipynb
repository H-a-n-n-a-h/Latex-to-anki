# %%
import numpy as np
import pandas as pd


# display everything
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
loaded_arr = np.load('array_maths.npy', allow_pickle=True)

pd.DataFrame(list(loaded_arr))
# Out:
#                                                   name  \
# 0                                       2,3,4, \dots \
# 1                                                    t
# 2                                               align*
# 3                                         ||\Delta x||
# 4                                                  abs
# 5                                                  rel
# 6                                        Gruppe; Group
# 7                       abelsche Gruppe; abelian group
# 8                                Untergruppe; subgroup
# 9    die von $g$ erzeugte Zyklische Gruppe; cyclic ...
# 10           zyklische Gruppe; cyclic group; å·¡å›žç¾¤
# 11   Linksnebenklasse; Left coset; coset representa...
# 12                         Menge der Linksnebenklassen
# 13                                    direktes Produkt
# 14                               Gruppenhomomorphismus
# 15                                Gruppenisomorphismus
# ...

# %%
data = {
    "Name": ["Gruppe"],
    "Description": ["Definition undso"],
    "Dependencies": ["Verknüpfung, Menge"],
    "Beispiel": ["G = {0}, + addition"],
    "Beweis": ["Entweder beweis von der Aussage, wohldefiniertheit der definition oder des beispiels."],
    "German": ["Gruppe"],
    "English": ["Group"],
    "Japanese": ["群"],
}

# Create the DataFrame
df = pd.DataFrame(data)
df
# Out:
#      Name       Description        Dependencies             Beispiel  \
# 0  Gruppe  Definition undso  Verknüpfung, Menge  G = {0}, + addition
#
#                                               Beweis  German English Japanese
# 0  Entweder beweis von der Aussage, wohldefiniert...  Gruppe   Group        群
