# %%
import numpy as np
import pandas as pd


# display everything
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None) 

loaded_arr = np.load('array_maths.npy', allow_pickle=True)

pd.DataFrame(list(loaded_arr))
# Out:
#                                                  name  \
# 0                                   Mengenoperationen
# 1                                          Mengenring
# 2                Ring der Elementargeometrische Menge
# 3                                    $\sigma$-Algebra
# 4                 Von epsilon erzeugte sigma algebra.
# 5                    Inhalt; Praemass; Mass; Massraum
# 6                                          Auschöpfen
# 7                             Abstandsmaß von A und B
# 8                          Endlich meßbar bzgl $\mus$
# 9                 Nullmenge und vollständiger Maßraum
# 10                                      Dynkin-System
# 11                        Von E erzeugte Dynkinsystem
# 12                                           Satz 1.1
# 13                                          Lemma 1.9
# 14                                               1.14
# 15                                  Mengenoperationen
# ...
