# %%
import numpy as np
import pandas as pd


# display everything
pd.set_option('display.max_rows', None) 
pd.set_option('display.max_columns', None)

# %%
loaded_arr = np.load('array_maths.npy', allow_pickle=True)

pd.DataFrame(list(loaded_arr))
# Out:
#                                                   name  \
# 0                                        Gruppe; Group
# 1                       abelsche Gruppe; abelian group
# 2                                Untergruppe; subgroup
# 3    die von $g$ erzeugte Zyklische Gruppe; cyclic ...
# 4            zyklische Gruppe; cyclic group; å·¡å›žç¾¤
# 5    Linksnebenklasse; Left coset; coset representa...
# 6                          Menge der Linksnebenklassen
# 7                                     direktes Produkt
# 8                                Gruppenhomomorphismus
# 9                                 Gruppenisomorphismus
# 10                               Gruppenautomorphismus
# 11                                   Isomorphe Gruppen
# 12                       Normalteiler; normal subgroup
# 13                                Alternierende Gruppe
# 14                                konjugierte Elemente
# 15                                  Konjugationsklasse
# 16                             konjugierte Untergruppe
# 17                                             Zentrum
# 18                            Element der Faktorgruppe
# 19   Faktorgruppe von G nach N; Quotient group; Fac...
# 20          NatÃ¼rlicher Homomorphismus; Canonical Map
# 21                               Element der Ordnung n
# 22                           Untergruppenverband von G
# 23                                     Diedergruppe Dn
# 24                                                Ring
# 25                              SchiefkÃ¶rper; KÃ¶rper
# 26               IntegritÃ¤tsring; IntegritÃ¤tsbereich
# 27                                        K-Vektorraum
# 28                          Untervektorraum; Unterraum
# 29                                           K-Algebra
# 30          Ringhomomorphismus; Algebrenhomomorphismus
# 31                                           Unterring
# 32                                         TeilkÃ¶rper
# 33                                  KÃ¶rpererweiterung
# 34                                        Unteralgebra
# 35                                               Ideal
# 36                lemma 6.3: Von a erzeugte Hauptideal
# 37                   Hauptidealring; Hauptidealbereich
# 38                                           Kongruenz
# 39                          Restklassenring modulo $n$
# 40                                   Aktion; Operation
# 41                                              G-Bahn
# 42                                          Bahnenraum
# 43   Standarduntergruppe; Stabilisator; Isotropiegr...
# 44   Anwendung der SylowsÃ¤tze auf Gruppe Ordnugn 1...
# 45                                     Einfache Gruppe
# 46   Normalreihe; abelsch; zyklisch; prim-zyklisch;...
# 47                                        G auflÃ¶sbar
# 48                 Euklidischer Ring; GrÃ¶ÃŸenfunktion
# 49   Teiler; Vielfaches; Einheit; irreduzibel; Prim...
# 50                                          Faktoriell
# 51                      Polynom; grad; Leitkoeffizient
# 52                                   Ring der Polynome
# 53                                   QuotientenkÃ¶rper
# 54   Unter welcher bedingung ist ein x automatisch ...
# 55                             Element ganz Ã¼ber Ring
# 56                        Ring ganz abgeschlossen in K
# 57                                irreduzible Polynome
# 58                            ggT; GCD;æœ€å¤§å…¬ç´„æ•°
# 59                                         Teilerfremd
# 60                                              Inhalt
# 61                                  normiertes Polynom
# 62                     Kx; Proposition; Ringadjunktion
# 63   K(x) aus K durch Adjunktion des Elementes x ge...
# 64   Algebraische bzw. transzendente Elemente bzw. ...
# 65                                      Minimalpolynom
# 66                                         KÃ¶rpergrad
# 67   Einfache KÃ¶rpererweiterung; algebraisch/trans...
# 68   K-Isomorphismus; K-Automorphismus; Morphismus ...
# 69                            Morphismus sternnotation
# 70   Berechne das Minimalpolynom von x = 2i + sqrt2...
# 71     Unmittelbar konstruierbar; Gerade; Kreis; Punkt
# 72                   Unmittelbar konstruierbare Punkte
# 73                                        Galoisgruppe
# 74                                          FixkÃ¶rper
# 75                                   Galoiserweiterung
# 76                                 ZerfÃ¤llungskÃ¶rper
# 77                         Charakteristik; PrimkÃ¶rper
# 78                                        Vielfachheit
# 79                                  Formale Derivation
# 80                                   Polynom separabel
# 81             x (aus algebraisch L Ã¼ber K) separabel
# 82                          Normale KÃ¶rpererweiterung
# 83                                          Kompositum
# 84                      Frobenius Endomorphismus von K
# 85                                   Perfekter KÃ¶rper
# 86                        KreisteilungskÃ¶rper Ã¼ber K
# 87              zyklische; abelsche KÃ¶rpererweiterung
# 88   einfache Radikalerweiterung; reines Polynom; R...
# 89                         Galoisgruppe eines Polynoms
# 90   Radikalerweiterung; Radikalturm; auflÃ¶sbare K...
# 91                                Gleichung auflÃ¶sbar
# 92                                 Fermatsche Primzahl
# 93   Was waren die wichtigsten Resultate der Gruppe...
# 94   Was ist der Satz von Lagrange und wie geht der...
# 95                      Was sind die drei SylowsÃ¤tze?
# 96                        Beweis des ersten Sylowsatz?
# 97         Was haben wir mit den SylowsÃ¤tzen gemacht?
# 98   Was kÃ¶nnen wir Ã¼ber Gruppen Ordnung 15 Aussa...
# 99            Ist eine Gruppe der Ordnung 105 einfach?
# 100  Warum folgt aus alpha(p) = 1; dass die Gruppe ...
# 101  Warum ist eine Gruppe der Ordnung 20 nicht ein...
# 102          Sind alle Gruppen der Ordnung 60 einfach?
# 103  Gibt es eine Gruppe der Ordnung 60 die einfach...
# 104                    Was ist eine auloesbare Gruppe?
# 105                       AuflÃ¶sbarkeit von Polynomen
# 106  Nenne Beispiel fÃ¼r KÃ¶rpererweiterung mit Gra...
# 107                    Was ist eine Galoiserweiterung?
# 108  Nenne Beispiel fÃ¼r Galoisgruppe; Galoiserrwei...
# 109  Gibt es eine KÃ¶rpererweiterung die nicht sepa...
# 110  Wie lautet der Hauptsatz der Galoistheorie? Un...
# 111  Was ist der Satz vom primitiven Element und wi...
# 112  Was sagt das AuflÃ¶sbarkeitskriterium und was ...
# 113              Existiert ein KÃ¶rper der Ordnung 15?
# 114  Zerlegung der Nebenklassen; Disjoint union of ...
# 115                                           Lagrange
# 116                  Satz Ã¼ber zyklische Untergruppen
# 117      Eigenschaften von einem Gruppenhomomorphismus
# 118                  Ã„quivalenzen zu gNg-1 subseteq N
# 119                                    Satz von Cayley
# 120                                   Klassengleichung
# 121              Satz Ã¼ber Faktorgruppe von Z nach Zn
# 122  Homomorphiesatz (Ã¼ber Normalteiler); Unique e...
# 123                         Satz Ã¼ber Isomorphie zu Z
# 124        Satz von Cauchy 1845 Ã¼ber endliche Gruppen
# 125                                   Ideal von Ring Z
# 126  Ein kommutativer Ring R ist ein KÃ¶rper genau ...
# 127                             Faktorring; R modulo I
# 128                         Homomorphiesatz fÃ¼r Ringe
# 129  Z/nZ Faktorring und n grÃ¶ÃŸergleich 1; dann i...
# 130                                    Bahnenzerlegung
# 131     1. Sylowscher Satz (1872); p-Sylowgruppe von G
# 132                          2. Sylowscher Satz (1872)
# 133                          3. Sylowscher Satz (1872)
# 134               Gruppen der Ordnung Primzahlenfaktor
# 135  Es gibt keine nicht-abelsche einfache Gruppe $...
# 136                                        Jordan 1870
# 137  Jede Untergruppe H einer auflÃ¶sbaren Gruppe G...
# 138  Faktorgruppen auflÃ¶sbarer Gruppen modulo eine...
# 139  Sein N ein Normalteiler in der Gruppe G. Sind ...
# 140               Jede abelsche Gruppe ist auflÃ¶sbar?
# 141        Jede Gruppe gerader Ordnung ist auflÃ¶sbar?
# 142                     FÃ¼r $n \geq 5$ ist $\Ss_n$...
# 143  Sei G eine endliche Gruppe. Es ist G auflÃ¶sba...
# 144                      Jeder Euklidische Ring ist...
# 145  Ã„quivalenzen fÃ¼r einen IntegritÃ¤tsbereich R...
# 146        Euklids Lemma: Jedes irreduzible Element...
# 147                        Jeder Hauptidealring ist...
# 148                Satz Ã¼ber Polynomdivision mit Rest
# 149  GauÃŸ: Wenn R ein faktorieller Ring ist dann i...
# 150                           Kriterium von Eisenstein
# 151                   Charakterisierung Minimalpolynom
# 152  1.9 LK KÃ¶rpererweiterung mit x in L algebrais...
# 153    1.10 Jede endliche KÃ¶rpererweiterung LK ist...
# 154           Charakterisierung algebraischer Elemente
# 155                          Satz von Kronecker (1887)
# 156
# 157
# 158                                           Gradsatz
# 159                                    Gradsatz Zusatz
# 160   Charakterisierung endlicher KÃ¶rpererweiterungen
# 161  5.3 M ist Menge aus 0 und 1; dann ist K(M) der...
# 162  z Komplexe Zahl konstruierbar genau dann; wenn...
# 163                   Isomorphismen-Erweiterungs-Lemma
# 164  Existenz von ZerfÃ¤llungskÃ¶rpern; Kronecker 1887
# 165                   Isomorphismen-Erweiterungs-Lemma
# 166  Derivationskriterium fÃ¼r Einfachheit von Null...
# 167  f in KT nicht konstantes Polynom und L ZerfÃ¤l...
# 168  Jede endliche Erweiterung LK von einem KÃ¶rper...
# 169  LK endliche KÃ¶rpererweiterung dann gilt: LK n...
# 170  Jede endliche KÃ¶rpererweiterung LK besitzt ei...
# 171                                EinschrÃ¤nkungssatz
# 172                                     Satz von Artin
# 173          Charakterisierung von Galoiserweiterungen
# 174                        Hauptsatz der Galoistheorie
# 175            Untergruppen von Einheitengruppen sind?
# 176                            Galois 1830; Moore 1893
# 177  Klassifikattion endlicher KÃ¶rper bezÃ¼glich e...
# 178                          Steinitz Perfekte KÃ¶rper
# 179     Steinitz Satz Ã¼ber die ZwischenkÃ¶rper (1910)
# 180                        Satz vom primitiven Element
# 181             Wann ist Gal(En(K)/K) isomorph zu was?
# 182                                             Galois
# 183                      natÃ¼rliche IrrationalitÃ¤ten
# 184                AuflÃ¶sbarkeitskriterim Galois 1831
# 185  Es gibt keine Formel fÃ¼r f grad prim und grÃ¶...
# 186  Satz von Gauss 1796/1801 konstruierbarkeit zet...
#
#                                                   main example proof  \
# 0    $G \neq \emptyset$ mit VerknÃ¼pfung $\cdot: G ...       0     0
# 1    $G$ Gruppe und $\forall x,y \in G$ gilt    $$ ...       0     0
# 2    $U \subseteq G$ und $G$ gruppe    \begin{enume...       0     0
# 3    $G$ Gruppe und $g \in G$, dann ist    $$    \l...       0     0
# 4    $G$ Gruppe heiÃŸt zyklisch, falls     $$    \e...       0     0
# 5    $G$ Gruppe, $U$ Untergruppe, $g \in G$    $$  ...       0     0
# 6    $G$ Gruppe, $U$ Untergruppe, $gU$ Linksnebenkl...       0     0
# 7    $G$ und $H$ Gruppen, $G \times H$ vermÃ¶ge    ...       0     0
# 8    $G$ und $H$ Gruppen, $f:G \to H$ Abbildung mit...       0     0
# 9    $G$ und $H$ Gruppen, $f:G \to H$ Gruppenhomomo...       0     0
# 10   $G$ und $H$ Gruppen, $f:G \to H$ Gruppenhomomo...       0     0
# 11   $G$ und $H$ sind isomorph ($\simeq$) zueinande...       0     0
# 12   $G$ Gruppen, $N$ Untergruppe, wenn fÃ¼r alle $...       0     0
# 13   $\A_n$ enthÃ¤lt alle geraden Permutationen und...       0     0
# 14   $G$ Gruppe, $x,y \in G$. Falls    $$    \exist...       0     0
# 15   $G$ Gruppe, $x,y \in G$ Dann ist    $$    C(x)...       0     0
# 16   $G$ Gruppe, $U$ Untergruppe, Dann ist       $$...       0     0
# 17   $G$ Gruppe, Wir nennen    $$    Z(G) := \{ x \...       0     0
# 18   $G$ Gruppe, $N \lhd G$ Normalteiler, dann schr...       0     0
# 19   $G$ Gruppe, $N \lhd G$ Normalteiler, $G / N$ L...       0     0
# 20   $G$ Gruppe, $N \lhd G$ Normalteiler, dann nenn...       0     0
# 21   $G$ Gruppe, $g \in G$, dann nennen wir die kle...       0     0
# 22   $G$ Gruppen dann nennen wir     $$    \text{ D...       0     0
# 23   $n \geq 1$    $$    \D_n := \langle r,s \rangl...       0     0
# 24   Eine Menge $R$ mit zwei VerknÃ¼pfungen    $$  ...       0     0
# 25   Ring $R$, wobei $R^\times = R \backslash \{0\}...       0     0
# 26   Ein kommutativer Ring $R$ mit $0 \neq 1$ und n...       0     0
# 27   $K$ KÃ¶rper, $V$ Menge mit innerer VerknÃ¼pfun...       0     0
# 28   $V$ K-Vektorraum, $W\subseteq V$ Teilmenge, Fa...       0     0
# 29   $R = (R,+, \cdot )$ Ring mit 1, $K$ KÃ¶rper (o...       0     0
# 30   \begin{enumerate}    \item     $R$ und $S$ Rin...       0     0
# 31   $R$ Ring, $S \subseteq R$ Teilmenge, falls    ...       0     0
# 32   $R$ Ring, $S$ Unterring von $R$, falls $S$ ein...       0     0
# 33   $R$ KÃ¶rper, $S$ Unterring von $R$, falls $S$ ...       0     0
# 34   $R$ ist eine K-Algebra,  $S$ ein Unterraum von...       0     0
# 35   $R$ Ring, $I\subseteq R$ Teilmenge falls    \b...       0     0
# 36   $R$ kommutativer Ring, $a \in R$    \begin{ali...       0     0
# 37   $I$ IntegritÃ¤tsring, wenn jedes Ideal von $I$...       0     0
# 38   Sei I ein Ideal in R, seien $a, b \in R$. Man ...       0     0
# 39   Wir nennen den Faktorring $\mathbb{Z}/n\mathbb...       0     0
# 40   $G$ Gruppe, $M$ Menge. Die Abbildung    \begin...       0     0
# 41   $G \times M \to M, \quad (g,m) \mapsto g.m$ Gr...       0     0
# 42   $G \times M \to M, \quad (g,m) \mapsto g.m$ Gr...       0     0
# 43   $G \times M \to M, \quad (g,m) \mapsto g.m$ Gr...       0     0
# 44   $G$ mit $|G| = 15 = 3 \cdot 5$ Dann gilt\begin...       0     0
# 45   $G$ Gruppe, falls $G \neq \{e\}$, und $G$ und ...       0     0
# 46   $G$ Gruppe, Falls fÃ¼r eine Kette von Untergru...       0     0
# 47   $G$ Gruppe, fals es eine Normalreihe fÃ¼r $G$ ...       0     0
# 48   IntegritÃ¤tsbereich $R$ mit $\sigma$ \textbf{g...       0     0
# 49   $R$ IntegritÃ¤tsbereich, $a,b \in R$    \begin...       0     0
# 50   IntegritÃ¤tsbereich $R$, falls jede Nichteinhe...       0     0
# 51   $K$ kommutativer Ring, $T$ eine unbestimmte, $...       0     0
# 52   $K$ kommutativer Ring, $f_n,g_n$ Funktionenfol...       0     0
# 53   $R$ IntegritÃ¤tsbereich. Dann      Sei $X = (a...       0     0
# 54   $R$ faktorieller Ring, $K$ QuotientenkÃ¶rper d...       0     0
# 55   $R$ Ring, $S$ Oberring von $R$,$x \in S$, fall...       0     0
# 56   $R$ faktorieller Ring mit QuotientenkÃ¶rper $K...       0     0
# 57   \begin{enumerate}        \item $R$ IntegritÃ¤t...       0     0
# 58   $R$ IntegritÃ¤tsbereich, $a,b,d \in R$ falls g...       0     0
# 59                Wenn $a,b \in R$ mit $ggt(a,b) = 1$.       0     0
# 60   $R$ faktoriell, $f = \sum_{i=0}^na_iT^i \in K[...       0     0
# 61   $R$ Ring, $f \in R[T]$ mit $f \neq 0$. Falls d...       0     0
# 62   $L/K$ KÃ¶rpererweiterung, $L,K$ KÃ¶rper,$n\geq...       0     0
# 63   $L/K$ KÃ¶rpererweiterung, $L,K$ KÃ¶rper, $x \i...       0     0
# 64   $L/K$ KÃ¶rpererweiterung, $x \in L$. Fall es e...       0     0
# 65   $L/K$ KÃ¶rpererweiterung, $x \in L$ algebraisc...       0     0
# 66   $L/K$ KÃ¶rpererweiterung,     \begin{align*}  ...       0     0
# 67   $L/K$ KÃ¶rpererweiterung. Falls es $x \in L$ g...       0     0
# 68   $L/K$, $L'/K'$ KÃ¶rpererweiterungen    \begin{...       0     0
# 69   $\sigma: R \to S$ Ringmorphismus. Wie definier...       0     0
# 70                                                           0     0
# 71   $M$ Teilmenge von $\C$ mit $1,0$    \begin{enu...       0     0
# 72   $M^{(0)} = M$ und $M^{n+1}$ rekursiv erklÃ¤rt ...       0     0
# 73   $L/K$ KÃ¶rpererweiterung, Wir bezeichnen $Gal(...       0     0
# 74   $L$ KÃ¶rper, $G$ Gruppe von Automorphismen $\s...       0     0
# 75   $L/K$ algebraische KÃ¶rpererweiterung, falls $...       0     0
# 76   $K$ KÃ¶rper, $f\in K[T]$mit $f\neq0$ falls    ...       0     0
# 77   $K$ KÃ¶rper, wenn es keine ganze Zahl $n\geq 1...       0     0
# 78   $L/K$ KÃ¶rpererweiterung, $0 \neq f \in K[T]$,...       0     0
# 79   $K$ KÃ¶rper, formale Derivation ist definiert ...       0     0
# 80   $f\in K[T]$ irreduzibles Polynom. Falls es in ...       0     0
# 81   $L/K$ KÃ¶rpererweiterung, $x \in L$ algebraisc...       0     0
# 82   $L/K$ algebraische KÃ¶rpererweiterung, falls f...       0     0
# 83   $M/K$ endliche KÃ¶rpererweiterungm $L_1, \dots...       0     0
# 84   $K$ KÃ¶rper mit Charakteristik $p > 0$.    Dan...       0     0
# 85   $K$ KÃ¶rper. Wenn jedes (nicht-konstante) Poly...       0     0
# 86   $K$ KÃ¶rper, $\N \ni n \geq 1$, $E_n(K) := $ Z...       0     0
# 87   $L/K$ KÃ¶rpererweiterung. Falls $L/K$ galoissc...       0     0
# 88   \begin{enumerate}    \item $L/K$ KÃ¶rpererweit...       0     0
# 89   $K$ KÃ¶rper, $f \in K[T]$ ein separables Polyn...       0     0
# 90   $L/K$ KÃ¶rpererweiterung, fall es \textbf{Radi...       0     0
# 91   $f \in K[T]$. Falls der ZerfÃ¤llungskÃ¶rper vo...       0     0
# 92   Eine ungerade Primzahl $p$ heiÃŸt \textbf{Ferm...       0     0
# 93                                                           0     0
# 94   \textbf{Beweis.} Sei $G$ endlich also $|G| = n...       0     0
# 95   Sylowscher Satz (1872):Es sei $G$ eine Gruppe ...       0     0
# 96   Beweis. Induktion nach $|G|$. FÃ¼r $|G|=1$ ode...       0     0
# 97   Gibt Aussage fÃ¼r viele Gruppen, ob einfach is...       0     0
# 98   $|G| = 15 = 3 \cdot 5$. Es gibt genau eine Unt...       0     0
# 99                                                           0     0
# 100  $\alpha(p) = 1$ bedeutet, dass es fÃ¼r dieses ...       0     0
# 101  Es gilt $20 = 4 \cdot 5 =: a \cdot p$ und wege...       0     0
# 102  Nein, $\Z_{60}$ hat Ordnung 60 und ist nicht e...       0     0
# 103  $\A_5$ ist die sind die geraden Permutationen....       0     0
# 104  \textbf{Gruppe auflÃ¶sbar Def.}    $G$ \textbf...       0     0
# 105                                                          0     0
# 106  \ \\\begin{enumerate}    \item \textbf{KÃ¶rper...       0     0
# 107  \ \\\begin{enumerate}    \item $K$ KÃ¶rper und...       0     0
# 108  \begin{enumerate}    \item \textbf{Galoisgrupp...       0     0
# 109                                                          0     0
# 110  \ \\\textbf{Aussage:}    $L/K$ endliche Galois...       0     0
# 111  \begin{enumerate}        \item \textbf{Satz:} ...       0     0
# 112                                                          0     0
# 113  Nein. Es gibt kein $p^n= 15$. Man kann allgeme...       0     0
# 114  $G$ Gruppe, $U$ Untergruppe,$G/U$ Menge von Li...       0     0
# 115  $G$ endliche Gruppe, $U$ Untergruppe,$G/U$ Men...       0     0
# 116  $G$ zyklische Gruppe     $$\Rightarrow U<G \te...       0     0
# 117  $f:G \to H$ Gruppenhomomorphismus dann gilt   ...       0     0
# 118  \begin{enumerate}        \item $gNg^{-1}\subse...       0     0
# 119  Sei $G$ eine endliche Gruppe der Ordnung $n$. ...       0     0
# 120  $G$ endliche Gruppe, $Z(G)$ Zentrum von $G$, $...       0     0
# 121  FÃ¼r jedes natÃ¼rliche $n\geq 1$ ist     $$   ...       0     0
# 122  $f:G \to H$ Gruppenhomomorphismus, $N \lhd G$ ...       0     0
# 123  \begin{enumerate}        \item Jede unendliche...       0     0
# 124  $G$ endliche Gruppe,$p$ prim,$n = |G|$ und $p ...       0     0
# 125            In $\Z$ ist jedes Ideal ein Hauptideal.       0     0
# 126                       ... R hat genau zwei Ideale.       0     0
# 127  $R$ Ring, $I \subseteq R$ Ideal, $R/I$ Faktorg...       0     0
# 128  $R, S$ Ringe, $f:R \to S$ Ringhomomorphismus. ...       0     0
# 129  $\Z_n$ ist ein IntegritÃ¤tsbereich genau dann,...       0     0
# 130  $G$ Gruppe, $M$ Menge, $M/G$ Bahnenraum, $B$ B...       0     0
# 131  $G$ Gruppe, $|G| = p^n \cdot m$, $m \nmid p$, ...       0     0
# 132  Je zwei p-Sylowgruppen von $G$ sind zueinander...       0     0
# 133  $G$ Gruppe, $|G| = p^n \cdot m$, $m \nmid p$, ...       0     0
# 134  $p < q$ Primzahlen mit $p \nmid (q-1)$, $G$ Gr...       0     0
# 135                               ...$1 \leq |G| < 60$       0     0
# 136  FÃ¼r $n \geq 5$ ist die alternierende Gruppe $...       0     0
# 137                                     ...auflÃ¶sbar.       0     0
# 138  ...auflÃ¶sbar. Also d.h. sei $\pi: G \to H$ su...       0     0
# 139                              ...G auch auflÃ¶sbar.       0     0
# 140                                                Ja.       0     0
# 141                        Ja. Satz von Feit-Thompson.       0     0
# 142                                ...nicht auflÃ¶sbar       0     0
# 143  es eine Normalreihe fÃ¼r $G$ gibt, die prim-zy...       0     0
# 144                             ...ein Hauptidealring.       0     0
# 145  IntegritÃ¤tsbereich $R$, dann ist Ã¤quivalent ...       0     0
# 146                                       ...ist prim.       0     0
# 147                                     ...faktoriell.       0     0
# 148  $K$ KÃ¶rper, $f,g \in K[T]$ mit $g\neq 0$, dan...       0     0
# 149  \begin{enumerate}    \item $\Rightarrow$ $R[T]...       0     0
# 150  $R$ faktorieller Ring mit QuotientenkÃ¶rper $K...       0     0
# 151  $L/K$ KÃ¶rpererweiterung, $x \in L$ algebraisc...       0     0
# 152  \begin{enumerate}        \item $fK[T] = Kern(\...       0     0
# 153  algebraisch bzw. genau gilt ist $[L:K] = n$, s...       0     0
# 154  $L/K$ KÃ¶rpererweiterung, $x \in L$, dann sind...       0     0
# 155  $K$ KÃ¶rper, $f \in K[T]$ normiert und irreduz...       0     0
# 156  $K(\alpha)/K, K(\beta)/K$ einfach algebraische...       0     0
# 157  $K,L$ KÃ¶rper, $i:K \to L$ Isomorphismus, $K(\...       0     0
# 158  $K\subseteq L\subseteq M$ KÃ¶rperturm, es gilt...       0     0
# 159  $K \subseteq L \subseteq M$ KÃ¶rperturm, $l_1,...       0     0
# 160  $L/K$ KÃ¶rpererweiterung, dann ist Ã¤quivalent...       0     0
# 161  \begin{enumerate}    \item $z \in K \Rightarro...       0     0
# 162  ...Es gibt einen KÃ¶rperturm     \begin{align*...       0     0
# 163  $K(x) / K, K'(x') / K'$ einfache algebraische ...       0     0
# 164  $K$ KÃ¶rper, $f \in K[T]$ mit $f\neq 0$. Dann ...       0     0
# 165  $i: K \to K'$ KÃ¶rperisomorphismus, $f \in K[T...       0     0
# 166  $K$ KÃ¶rper, $0 \neq f \in K[T]$ ein Polynom  ...       0     0
# 167  \ \\\begin{enumerate}    \item     FÃ¼r jeden ...       0     0
# 168                                      ...separabel.       0     0
# 169  $L/K$ ist ZerfÃ¤llungskÃ¶rper eines Polynoms i...       0     0
# 170  ...normalen Abschluss. Dieser ist deiniert als...       0     0
# 171  $L/K$ endliche KÃ¶rpererweiterung, dann ist Ã¤...       0     0
# 172  $L$ KÃ¶rper, $G$ endliche Gruppe von Automorph...       0     0
# 173  $L/K$ endliche KÃ¶rpererweiterung. Dann ist Ã¤...       0     0
# 174  $L/K$ endliche Galoiserweiterung mit Galoisgru...       0     0
# 175  $K$ KÃ¶rper, $E(K) = (K\backslash\{0\}, \cdot)...       0     0
# 176  $q = p^n$ mit p prim und $n \geq 1$. Dann gilt...       0     0
# 177  \begin{enumerate}    \item \textbf{Satz 12.2} ...       0     0
# 178  $K$ KÃ¶rper    \begin{enumerate}        \item ...       0     0
# 179  $L/K$ endliche KÃ¶rpererweiterung.    Es gibt ...       0     0
# 180  $L/K$ endliche KÃ¶rpererweiterung, $L/K$ separ...       0     0
# 181  $n \geq 1$, $K$ KÃ¶rper mit Char(K) $= a$ und ...       0     0
# 182  $K$ KÃ¶rper, der primitive n-te Einheitswurzel...       0     0
# 183  $L/K$ endliche Galoiserweiterung also $L= (\al...       0     0
# 184  $K$ KÃ¶rper mit $char(K) = 0$, $f \in K[T]$.  ...       0     0
# 185  $p \in \P, f\in\Q[T]$ irreduzibel vom Grad $p$...       0     0
# 186  $n \geq 1$ natÃ¼rliche Zahl, $\zeta \in \C$ ei...       0     0
#
#            type
# 0    definition
# 1    definition
# 2    definition
# 3    definition
# 4    definition
# 5    definition
# 6    definition
# 7    definition
# 8    definition
# 9    definition
# 10   definition
# 11   definition
# 12   definition
# 13   definition
# 14   definition
# 15   definition
# 16   definition
# 17   definition
# 18   definition
# 19   definition
# 20   definition
# 21   definition
# 22   definition
# 23   definition
# 24   definition
# 25   definition
# 26   definition
# 27   definition
# 28   definition
# 29   definition
# 30   definition
# 31   definition
# 32   definition
# 33   definition
# 34   definition
# 35   definition
# 36   definition
# 37   definition
# 38   definition
# 39   definition
# 40   definition
# 41   definition
# 42   definition
# 43   definition
# 44   definition
# 45   definition
# 46   definition
# 47   definition
# 48   definition
# 49   definition
# 50   definition
# 51   definition
# 52   definition
# 53   definition
# 54   definition
# 55   definition
# 56   definition
# 57   definition
# 58   definition
# 59   definition
# 60   definition
# 61   definition
# 62   definition
# 63   definition
# 64   definition
# 65   definition
# 66   definition
# 67   definition
# 68   definition
# 69   definition
# 70   definition
# 71   definition
# 72   definition
# 73   definition
# 74   definition
# 75   definition
# 76   definition
# 77   definition
# 78   definition
# 79   definition
# 80   definition
# 81   definition
# 82   definition
# 83   definition
# 84   definition
# 85   definition
# 86   definition
# 87   definition
# 88   definition
# 89   definition
# 90   definition
# 91   definition
# 92   definition
# 93   definition
# 94   definition
# 95   definition
# 96   definition
# 97   definition
# 98   definition
# 99   definition
# 100  definition
# 101  definition
# 102  definition
# 103  definition
# 104  definition
# 105  definition
# 106  definition
# 107  definition
# 108  definition
# 109  definition
# 110  definition
# 111  definition
# 112  definition
# 113  definition
# 114        satz
# 115        satz
# 116        satz
# 117        satz
# 118        satz
# 119        satz
# 120        satz
# 121        satz
# 122        satz
# 123        satz
# 124        satz
# 125        satz
# 126        satz
# 127        satz
# 128        satz
# 129        satz
# 130        satz
# 131        satz
# 132        satz
# 133        satz
# 134        satz
# 135        satz
# 136        satz
# 137        satz
# 138        satz
# 139        satz
# 140        satz
# 141        satz
# 142        satz
# 143        satz
# 144        satz
# 145        satz
# 146        satz
# 147        satz
# 148        satz
# 149        satz
# 150        satz
# 151        satz
# 152        satz
# 153        satz
# 154        satz
# 155        satz
# 156        satz
# 157        satz
# 158        satz
# 159        satz
# 160        satz
# 161        satz
# 162        satz
# 163        satz
# 164        satz
# 165        satz
# 166        satz
# 167        satz
# 168        satz
# 169        satz
# 170        satz
# 171        satz
# 172        satz
# 173        satz
# 174        satz
# 175        satz
# 176        satz
# 177        satz
# 178        satz
# 179        satz
# 180        satz
# 181        satz
# 182        satz
# 183        satz
# 184        satz
# 185        satz
# 186        satz
